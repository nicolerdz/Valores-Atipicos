# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolerdz/Valores-Atipicos/blob/main/2021_4_Valores_at%C3%ADpicos_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATOS LIMPIOS 2021 VALORES ATIPICOS DATAFRAME**
# Nicole Aryam Rodríguez

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_excel('Gastos y costos 20-23 (1).xlsx', sheet_name = '2021')

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3035 non-null   datetime64[ns]
#  1   FOLIO        2888 non-null   object
#  2   UUID         3035 non-null   object
#  3   RFC          3035 non-null   object
#  4   PROVEEDOR    3035 non-null   object
#  5   TIPO GASTO   3035 non-null   object
#  6   DESCRIPCION  3035 non-null   object
#  7   MP           2381 non-null   object
#  8   TC           3035 non-null   float64
#  9   IMPORTE      3035 non-null   float64
#  10  IVA          3035 non-null   float64
#  11  RET ISR      3035 non-null   float64
#  12  RET IVA      3035 non-null   float64
#  13  TOTAL MX     3035 non-null   float64
#  14  TOTAL SAT    3035 non-null   float64
#  15  TIPO         3035 non-null   object
#  16  STATUS       3035 non-null   object
#  17  POLIZA       663 non-null    object
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO           147
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# DESCRIPCION       0
# MP              654
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              0
# STATUS            0
# POLIZA         2372
# dtype: int64

# %% [markdown]
# **PROCEDIMIENTO PARA ELIMINAR VALORES NULOS EN DATAFRAME**

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         6
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "mean"
#Realizamos una copia del dataframe
data2=data1.copy()
data2['POLIZA']= data2['POLIZA'].fillna('NO POLIZA')
data2
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data2.iloc[:,9:15]
x = data2.iloc[:, list(range(0, 9)) + list(range(15, 18))]

Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido IMPORTE      36154.569820
# IVA           5464.876801
# RET ISR        900.150092
# RET IVA       1200.884906
# TOTAL MX     40680.462408
# TOTAL SAT    40671.985064
# dtype: float64
# Limite inferior permitido IMPORTE     -27625.812771
# IVA          -4276.811367
# RET ISR       -833.428945
# RET IVA      -1053.848939
# TOTAL MX    -31176.694132
# TOTAL SAT   -31129.503410
# dtype: float64

# %%
#Encontramos Ouliers del Dataframe
outliers= y[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#       IMPORTE  IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0         NaN  NaN      NaN      NaN       NaN        NaN
# 1         NaN  NaN      NaN      NaN       NaN        NaN
# 2         NaN  NaN      NaN      NaN       NaN        NaN
# 3         NaN  NaN      NaN      NaN       NaN        NaN
# 4         NaN  NaN      NaN      NaN       NaN        NaN
# ...       ...  ...      ...      ...       ...        ...
# 3030      NaN  NaN      NaN      NaN       NaN        NaN
# 3031      NaN  NaN      NaN      NaN       NaN        NaN
# 3032      NaN  NaN      NaN      NaN       NaN        NaN
# 3033      NaN  NaN      NaN      NaN       NaN        NaN
# 3034      NaN  NaN      NaN      NaN       NaN        NaN
#
# [3035 rows x 6 columns]

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= y[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
#        IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0       490.00   78.40      0.0      0.0    568.40     568.40
# 1       345.00   55.20      0.0      0.0    400.20     400.20
# 2      3447.41  551.59      0.0      0.0   3999.00    3999.00
# 3      5551.38  888.22      0.0      0.0   6439.60    6439.60
# 4      5551.98  888.32      0.0      0.0   6440.30    6440.30
# ...        ...     ...      ...      ...       ...        ...
# 3030      0.00    0.00      0.0      0.0      0.00       0.00
# 3031      0.00    0.00      0.0      0.0      0.00       0.00
# 3032  22826.46  705.58      0.0      0.0  23532.04   23532.04
# 3033      0.00    0.00      0.0      0.0      0.00       0.00
# 3034  15656.15    0.00      0.0      0.0  15656.15   15656.15
#
# [3035 rows x 6 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# IMPORTE      43
# IVA          38
# RET ISR      32
# RET IVA      81
# TOTAL MX     40
# TOTAL SAT    40
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data3.copy()
data_clean=data_clean.fillna(round(data3.mean(),1))
data_clean
# Out:
#        IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0       490.00   78.40      0.0      0.0    568.40     568.40
# 1       345.00   55.20      0.0      0.0    400.20     400.20
# 2      3447.41  551.59      0.0      0.0   3999.00    3999.00
# 3      5551.38  888.22      0.0      0.0   6439.60    6439.60
# 4      5551.98  888.32      0.0      0.0   6440.30    6440.30
# ...        ...     ...      ...      ...       ...        ...
# 3030      0.00    0.00      0.0      0.0      0.00       0.00
# 3031      0.00    0.00      0.0      0.0      0.00       0.00
# 3032  22826.46  705.58      0.0      0.0  23532.04   23532.04
# 3033      0.00    0.00      0.0      0.0      0.00       0.00
# 3034  15656.15    0.00      0.0      0.0  15656.15   15656.15
#
# [3035 rows x 6 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# dtype: int64

# %%
Datos_limpios1 = pd.concat([x, data_clean], axis=1)
Datos_limpios1
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %% [markdown]
# **PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2.iloc[:,9:15]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido \n", Limite_Superior_iqr)
print("Limite inferior permitido \n", Limite_Inferior_iqr)
# Out:
# Limite superior permitido
#  IMPORTE      10127.7125
# IVA           1381.4750
# RET ISR          0.0000
# RET IVA          0.0000
# TOTAL MX     11580.2750
# TOTAL SAT    11456.0225
# dtype: float64
# Limite inferior permitido
#  IMPORTE     -6076.6275
# IVA          -828.8850
# RET ISR         0.0000
# RET IVA         0.0000
# TOTAL MX    -6948.1650
# TOTAL SAT   -6818.3175
# dtype: float64

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= y[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#        IMPORTE  IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0          NaN  NaN      NaN      NaN       NaN        NaN
# 1          NaN  NaN      NaN      NaN       NaN        NaN
# 2          NaN  NaN      NaN      NaN       NaN        NaN
# 3          NaN  NaN      NaN      NaN       NaN        NaN
# 4          NaN  NaN      NaN      NaN       NaN        NaN
# ...        ...  ...      ...      ...       ...        ...
# 3030       NaN  NaN      NaN      NaN       NaN        NaN
# 3031       NaN  NaN      NaN      NaN       NaN        NaN
# 3032  22826.46  NaN      NaN      NaN  23532.04   23532.04
# 3033       NaN  NaN      NaN      NaN       NaN        NaN
# 3034  15656.15  NaN      NaN      NaN  15656.15   15656.15
#
# [3035 rows x 6 columns]

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= y[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#       IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0      490.00   78.40      0.0      0.0     568.4      568.4
# 1      345.00   55.20      0.0      0.0     400.2      400.2
# 2     3447.41  551.59      0.0      0.0    3999.0     3999.0
# 3     5551.38  888.22      0.0      0.0    6439.6     6439.6
# 4     5551.98  888.32      0.0      0.0    6440.3     6440.3
# ...       ...     ...      ...      ...       ...        ...
# 3030     0.00    0.00      0.0      0.0       0.0        0.0
# 3031     0.00    0.00      0.0      0.0       0.0        0.0
# 3032      NaN  705.58      0.0      0.0       NaN        NaN
# 3033     0.00    0.00      0.0      0.0       0.0        0.0
# 3034      NaN    0.00      0.0      0.0       NaN        NaN
#
# [3035 rows x 6 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# IMPORTE      336
# IVA          342
# RET ISR       56
# RET IVA      212
# TOTAL MX     347
# TOTAL SAT    351
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
data4_iqr
# Out:
#       IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0      490.00   78.40      0.0      0.0     568.4      568.4
# 1      345.00   55.20      0.0      0.0     400.2      400.2
# 2     3447.41  551.59      0.0      0.0    3999.0     3999.0
# 3     5551.38  888.22      0.0      0.0    6439.6     6439.6
# 4     5551.98  888.32      0.0      0.0    6440.3     6440.3
# ...       ...     ...      ...      ...       ...        ...
# 3030     0.00    0.00      0.0      0.0       0.0        0.0
# 3031     0.00    0.00      0.0      0.0       0.0        0.0
# 3032  1699.50  705.58      0.0      0.0    1903.4     1910.9
# 3033     0.00    0.00      0.0      0.0       0.0        0.0
# 3034  1699.50    0.00      0.0      0.0    1903.4     1910.9
#
# [3035 rows x 6 columns]

# %%
# Unimos la columna 'indice_tiempo' con el dataframe
Datos_limpios2 = pd.concat([x, data4_iqr], axis=1)
Datos_limpios2
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios2.isnull().sum()
valores_nulos
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# TIPO           0
# STATUS         0
# POLIZA         0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# dtype: int64

# %%
#Convertir DataFrame a CSV
Datos_limpios2.to_csv("2021Datos_limpiosQ.csv")
Datos_limpios1.to_csv("2021Datos_limpiosDE.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
#files.download("2021Datos_limpiosQ.csv")

#files.download("2021Datos_limpiosDE.csv")
